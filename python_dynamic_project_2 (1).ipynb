# %%
# !pip install bubbly

# %%
# import basic libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.offline as py
import bubbly
from bubbly.bubbly import bubbleplot

# %%
# Define File Path : Replace xxxxx with appropriate File Path
file_path = r'/content/Kevin Cookie Dataset.csv'

# Import & Read Dataset
df = pd.read_csv(file_path)

# Display Dataset Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     700 non-null    object
#  1   Product     700 non-null    object
#  2   Units Sold  700 non-null    int64
#  3   Revenue     700 non-null    int64
#  4   Cost        700 non-null    int64
#  5   Profit      700 non-null    int64
#  6   Date        700 non-null    object
# dtypes: int64(4), object(3)
# memory usage: 38.4+ KB

# %%
fig = px.scatter(df, x='Country', y='Units Sold', color='Revenue',
                 size='Profit', animation_frame='Date', title='Revenue vs Units Sold vs Profit Over Time',
                 labels={'Units Sold': 'Units Sold', 'Revenue': 'Revenue', 'Profit': 'Profit'},
                 size_max=90)

# Updating layout with play/pause buttons
fig.update_layout(updatemenus=[dict(type='buttons', showactive=False,
                                    buttons=[dict(label='Play',
                                                  method='animate',
                                                  args=[None, dict(frame=dict(duration=1000, redraw=True),
                                                                  fromcurrent=True)]),
                                            dict(label='Pause',
                                                  method='animate',
                                                  args=[[None], dict(frame=dict(duration=300, redraw=True),
                                                                    mode='immediate',
                                                                    transition=dict(duration=100))])])],
                 xaxis_title="Country", yaxis_title="Units Sold", coloraxis_colorbar=dict(title='Revenue'),
                 xaxis=dict(type='category'), height=600)

# Display the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Objective**
#
# Optimize Cost Structure for Improved Profit Margins:
#
# 1) Implement a thorough cost-benefit analysis to identify and address areas for cost optimization, ensuring a more efficient allocation of resources.
#
# 2) Focus on enhancing profitability by proactively responding to performance standards and swiftly adapting to changes, particularly investigating the root cause of the decline observed in March 2020.
#
# **Analysis**
#
# Revenue and sales are increasing and showing good growth. Profits are increasing, but at a slightly slower pace, which points to potential areas for cost optimization. India is currently the best performing country in terms of revenue, sales and profit.
#
# Some changes in performance occur over time; This highlights the importance of regular monitoring and review. Exclusive Analysis:As of October 1, 2020, India has the highest revenue (4488), highest sales (1496) and  highest profits (2618).
#
# Revenues increased in December 2020, driven by increased sales. Margins tend to be highest in India and the US. Revenues and sales decreased in March 2020; This may be due to other factors such as the COVID-19 pandemic. Recommendations:Focus only on sales growth in India, which has huge potential. Explore opportunities to expand into other emerging markets such as the UK and the Philippines.
#
# Conduct a cost-benefit analysis  to identify areas for improvement and added value. Pay close attention to performance standards and respond quickly to any changes. Consider  further analysis to determine the root cause of  the change, specifically the March 2020 decline.
#
# Check seasonal trends in sales and adjust strategies accordingly. Next steps:I will schedule a meeting with the sales and marketing team to discuss strategies for further growth in India and other  markets. I will work with the finance team to analyze the results of the expansion plan. I will use a more robust system to track and analyze performance data, including early warning signs of decline.

# %%
fig = px.scatter(df, x='Country', y='Units Sold',
                 animation_frame='Date', title='Units Sold vs Country Over Time',
                 labels={'Units Sold': 'Units Sold'},
                 size='Profit',  # Use 'Profit' to determine bubble size
                 color='Revenue',  # Use 'Revenue' as color scale
                 color_continuous_scale='viridis',  # Change the color scale
                 size_max=50)  # Increase the maximum circle size

# Updating layout with play/pause buttons
fig.update_layout(updatemenus=[dict(type='buttons', showactive=False,
                                    buttons=[dict(label='Play',
                                                  method='animate',
                                                  args=[None, dict(frame=dict(duration=1500, redraw=True),
                                                                  fromcurrent=True)]),
                                            dict(label='Pause',
                                                  method='animate',
                                                  args=[[None], dict(frame=dict(duration=500, redraw=True),
                                                                    mode='immediate',
                                                                    transition=dict(duration=500))])])],
                 xaxis_title="Country", yaxis_title="Units Sold", coloraxis_colorbar=dict(title='Revenue'),
                 xaxis=dict(type='category'), height=600)

# Display the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Objective**
#
# Maximize Sales Growth in Key Markets:
#
# 1) Focus on sustained efforts to enhance sales in India, the leading market, by implementing targeted strategies that leverage the country's significant growth potential.
#
# 2) Explore new opportunities for expansion in emerging markets such as the UK and the Philippines to diversify revenue sources and mitigate risks associated with dependency on specific regions.
#
# Enhance Operational Efficiency and Adaptability:
#
# 1) Conduct a comprehensive cost-benefit analysis to identify areas for operational improvement and added value, ensuring a streamlined cost structure.
#
# 2) Strengthen adaptability by closely monitoring performance standards, responding promptly to changes, and conducting in-depth analyses to understand the root causes of significant declines, such as the observed sales and revenue drop in March 2020.
#
# **Analysis**
#
# Sales increased in all four countries; The most significant growth was in India. Incomes also increased in all countries; India leads again. Margins tend to be highest in India and the US. Sales and revenue decreased significantly in March 2020, likely due to the COVID-19 pandemic.
#
# RecommendationsContinue to focus on sales growth in India, which has the greatest potential. Explore opportunities to expand into other emerging markets such as the UK and the Philippines. Conduct a cost-benefit analysis  to identify areas for improvement and added value. Pay close attention to performance standards and respond quickly to any changes. Consider  further analysis to determine the root cause of  the change, specifically the March 2020 decline.
#
# Check seasonal trends in sales and adjust strategies accordingly. Next stepsSchedule a meeting with the sales and marketing team to discuss strategies for further growth in India and other  markets. Work with the finance team to conduct  cost-benefit analysis of  expansion plans. Use more powerful systems to track and analyze performance data, including early warning signs of decline. Limited dataIt is important to note that this analysis is based on  limited data and may not be representative of the company's  performance.
#
# It was perfect. Additional data and analyzes are needed to draw further conclusions. ConclusionData shows that cafeterias experienced good sales in all four countries, with India performing best. However, there are some changes in performance that highlight the need for regular monitoring and review.
#
# By following the recommendations, the coffee shop can continue to  increase sales, increase profits and strengthen its position in the market.

# %%
fig = px.violin(df, x='Country', y='Units Sold', color='Product',
                animation_frame='Date', title='Animated Violin Plot of Units Sold by Country and Product',
                labels={'Units Sold': 'Units Sold'},
                hover_data=['Revenue', 'Cost', 'Profit'],  # Additional information on hover
                violinmode='overlay',  # Overlay the violins for each category
                height=600)

# Updating layout with play/pause buttons
fig.update_layout(updatemenus=[dict(type='buttons', showactive=False,
                                    buttons=[dict(label='Play',
                                                  method='animate',
                                                  args=[None, dict(frame=dict(duration=1500, redraw=True),
                                                                  fromcurrent=True)]),
                                            dict(label='Pause',
                                                  method='animate',
                                                  args=[[None], dict(frame=dict(duration=500, redraw=True),
                                                                    mode='immediate',
                                                                    transition=dict(duration=500))])])],
                 xaxis_title="Country", yaxis_title="Units Sold",
                 xaxis=dict(type='category'))

# Display the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Objective**
#
# Optimize Product Strategy for Target Markets:
#
# 1) Tailor product offerings and marketing strategies to each market based on the observed variations in product preferences, recognizing the specific factors that drive demand in each country.
#
# 2) Conduct detailed research on the factors contributing to the success of cookie sales in India, aiming to understand taste preferences, cultural influences, and effective marketing campaigns that can inform a refined marketing strategy for the Indian market.
#
# Diversify Market Presence and Adapt to Changing Conditions:
#
# 1) Strengthen the business focus on the high-performing market in India while exploring opportunities to increase sales in other markets, leveraging insights such as the popularity of oatmeal raisin cookies in the Philippines.
#
# 2) Develop adaptive business strategies to respond effectively to changing conditions, especially in light of external factors like the COVID-19 pandemic, which may involve innovating new products, exploring new markets, or revising existing business strategies for resilience.
#
# **Analysis**
#
# The chart shows the number of units sold for five different cookie products (Chocolate Chip, Fortune Cookie, Oatmeal Raisin, Snickerdoodle, and Sugar) across four countries (India, United Kingdom, Philippines, and Malaysia) from November 1, 2019, to December 1, 2020.India is the top-selling country for all five products, with the exception of Oatmeal Raisin cookies, where the Philippines takes the lead.Chocolate Chip cookies are the most popular product overall, followed by Fortune Cookies and Oatmeal Raisin cookies.Units sold for all products generally trended upwards over time, with a few exceptions.
#
# There was a notable dip in sales for all products in March 2020, which could be due to the COVID-19 pandemic.The distribution of units sold within each country varies by product. For example, in India, the distribution of units sold is relatively even across all five products, while in the United Kingdom, Chocolate Chip cookies are significantly more popular than the other products.InsightsIndia is a clear standout market for your cookies, with strong sales across all product lines.
#
# This suggests that there may be specific factors driving demand in India, such as taste preferences, cultural factors, or effective marketing campaigns.Chocolate Chip cookies are the most popular product overall, indicating that they have broad appeal across different markets. However, there is also some variation in product preferences by country, suggesting that it may be important to tailor your product offerings and marketing strategies to each market.
#
# The dip in sales in March 2020 is likely due to the COVID-19 pandemic. This highlights the importance of adapting to changes in business.
#
#  Recommendations: Focus only on your business in India as it is your strongest business. Consider conducting further research to understand the factors driving biscuit demand  in India. This can help you  develop a better marketing strategy for that market.  Look for opportunities to increase sales in other markets, such as the Philippines, where oatmeal raisin cookies are popular. Be prepared to adapt your business to changing business conditions, such as the COVID-19 pandemic. This may include developing new products, expanding into new markets or reviewing business strategies.

# %%
import plotly.express as px

# Assuming 'df' is your DataFrame
fig = px.bar(df, x='Country', y='Units Sold', color='Profit',
             animation_frame='Date', title='Rising Bar Graph of Units Sold by Country and Profit',
             labels={'Units Sold': 'Units Sold'},
             height=600)

# Updating layout with play/pause buttons
fig.update_layout(updatemenus=[dict(type='buttons', showactive=False,
                                    buttons=[dict(label='Play',
                                                  method='animate',
                                                  args=[None, dict(frame=dict(duration=1500, redraw=True),
                                                                  fromcurrent=True)]),
                                            dict(label='Pause',
                                                  method='animate',
                                                  args=[[None], dict(frame=dict(duration=500, redraw=True),
                                                                    mode='immediate',
                                                                    transition=dict(duration=500))])])],
                 xaxis_title="Country", yaxis_title="Units Sold",
                 xaxis=dict(type='category'))

# Display the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Objective**
#
# Conduct In-depth Market Analysis for Targeted Strategies:
#
# Undertake a detailed market analysis for each country, focusing on factors such as population demographics, economic conditions, and consumer preferences to develop targeted strategies for maximizing sales and sustaining growth in each specific market.
# Graph Analysis:
#
# The graph, titled "Profit," displays the units sold of a product in different countries over the period from September 1, 2019, to March 1, 2020. The x-axis represents the date, and the y-axis shows the number of units sold in thousands. Each country is color-coded, with India consistently leading in units sold, followed by the United Kingdom, the Philippines, Malaysia, and the United States.
#
# **Analysis**
#
# Overall Sales Trends:
#
# 1. Positive Growth: The graph illustrates a positive trend in overall sales, with the total units sold increasing steadily from approximately 2,000 in September 2019 to over 14,000 in March 2020. This indicates a growing demand for the product during the specified period.
#
# Country-Specific Analysis:
#
# 2. India:
#    - Consistent Leadership: India consistently stands out as the top-selling country, maintaining high sales figures throughout the period.
#    - Potential Market Size: The large population of India may contribute to its significant market share and robust sales.
#
# 3. United Kingdom:
#    - Steady Growth: The United Kingdom is the second-highest selling country, showing consistent growth in sales over time.
#    - Effective Market Presence: The product seems to have a stable and growing presence in the UK market.
#
# 4. Philippines and Malaysia:
#    - Volatility: Both the Philippines and Malaysia exhibit more volatile sales patterns, experiencing periods of both highs and lows.
#    - Factors at Play: Fluctuations in these countries could be influenced by various factors such as economic conditions, seasonal variations, or specific marketing strategies.
#
# 5. United States:
#    - Stable Sales: The United States shows relatively stable sales throughout the period, though not reaching the levels seen in India or the UK.
#    - Potential for Growth: While sales are consistent, exploring strategies to tap into the larger market may be considered.
#
# Possible Explanations for Trends:
#
# Market Size and Demographics: India's large population could contribute to its strong sales, while the UK's stable performance may be due to a favorable market demographic.
#
# Marketing and Distribution Effectiveness: Variances in sales could be attributed to the effectiveness of marketing and distribution channels in different countries.
#
# Product Suitability The product may align better with the preferences or needs of consumers in certain markets.
#
# Seasonality or Events:Fluctuations in some countries might be influenced by seasonal factors, economic conditions, or specific events.
#
# Additional Considerations:
#
# Profitability: It would be beneficial to assess profitability alongside units sold to gauge the overall financial success of the product in each country.
#
# Market Trends: Understanding broader market trends and monitoring competitor activity could provide valuable insights for strategic decision-making.
#
# Future Projections: Based on observed trends, forecasting future sales and adapting strategies accordingly can be crucial for sustained growth.
#
# While the graph highlights successful sales across multiple countries, further research into the specific factors influencing each market and a comprehensive understanding of profitability would enhance the ability to make informed business decisions. The provided analysis serves as a starting point for deeper exploration into the dynamics of the product's performance in different regions.

# %%
# Assuming 'df' is your DataFrame
df['Date'] = pd.to_datetime(df['Date'])  # Convert 'Date' to datetime
df['Month'] = df['Date'].dt.to_period('M')  # Extract month

fig = px.scatter(df, x='Revenue', y='Profit', size='Units Sold', color='Country',
                 animation_frame='Month', title='Scatter Plot of Revenue vs Profit over Time (Grouped by Month)',
                 labels={'Revenue': 'Revenue', 'Profit': 'Profit'},
                 height=600)

# Increase the animation frame duration to slow down the animation
fig.update_layout(updatemenus=[dict(type='buttons', showactive=False,
                                    buttons=[dict(label='Play',
                                                  method='animate',
                                                  args=[None, dict(frame=dict(duration=1500, redraw=True),
                                                                  fromcurrent=True)]),
                                            dict(label='Pause',
                                                  method='animate',
                                                  args=[[None], dict(frame=dict(duration=500, redraw=True),
                                                                    mode='immediate',
                                                                    transition=dict(duration=500))])])])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Objective**
#
#  Implement Seasonal Optimization Strategies:
#
#  Develop and implement targeted strategies to capitalize on the observed seasonal patterns, focusing on maximizing revenue and profit during autumn and winter months through tailored marketing campaigns, promotions, and product offerings.
#
# **Analysis**
#
# Relationship between revenue and profit: There is usually a relationship between revenue and profit, which means that when money comes in, profit will increase more. However, the data distribution shows that other factors also influence the results.
#
# Seasonal Pattern: The information clearly shows the seasonal pattern with higher income and good results in autumn and winter and lower income and results in spring and summer. This could be due to a number of factors, such as increased holiday spending, cold weather boosting hot water sales, or the launch of new seasonal products.
#
# Highest and lowest months: - The highest months in terms of revenue and profit are November and December 2019, followed by February and October 2020. In contrast, January and March 2020 were considered the lowest months in terms of revenue and profit. The reason behind this will be the appropriate distribution of needs.
#
# Geographic Performance:
#
# In the United States, data is converging and showing consistent performance from month to month. This stability could be advantageous for strategic planning.
#
# In India, the data is more spread out, indicating more variability in performance from month to month. Understanding the factors contributing to this variability is essential for targeted improvements.
#
# The Philippines and Malaysia show a spread-out data pattern, but there's an overall upward trend in revenue and profit. This suggests growth in these markets, possibly due to successful business strategies or increased market demand.
#
# Implications for Business Strategy:
#
# The coffee chain seems to be more profitable during the fall and winter months. Therefore we should explorie strategies on this seasonality, such as marketing campaigns, seasonal promotions, or introducing winter-themed products to increase the profitability of the coffee shops.
#
# Analyzing the successful consistency in the United States and growth in the Philippines and Malaysia could provide insights into effective business strategies. Meanwhile, addressing the variability in India may require a targeted approach to stabilize and improve performance.
# Caveats and Further Analysis:
#
# It's crucial to note that this analysis is based on a single data visualization, and more in-depth analysis, including statistical methods, would be necessary for definitive conclusions.
#
# Exploring additional variables such as marketing initiatives, competition, economic factors, or external events could provide a more comprehensive understanding of the observed patterns.
#
# In conclusion, while the initial analysis provides valuable insights, a more detailed examination considering multiple factors and statistical analysis would be essential for informed decision-making and strategy development for the coffee chain.
